# %%
import pandas as pd
from IPython.display import display

# %%
data = {
    "Logistic Regression(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "F1": 0.544,
        # "time_elapsed(m)": 0.0010570605595906575
    },
    "Random Forest(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "F1": 0.544,
        # "time_elapsed(m)": 0.08546341260274251
    },
    "Naive Bayes(Average Aggregation)": {
        "accuracy": 0.7673267326732673,
        "precision": 0.46017699115044247,
        "recall": 0.611764705882353,
        "F1": 0.5252525252525252,
        # "time_elapsed(m)": 0.0002043445905049642
    },
    "SVM(Average Aggregation)": {
        "accuracy": 0.8985148514851485,
        "precision": 0.8928571428571429,
        "recall": 0.5882352941176471,
        "F1": 0.7092198581560284,
        # "time_elapsed(m)": 0.0039326230684916174
    },
        "Logistic Regression(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.7896039603960396,
        "precision": 0.5,
        "recall": 0.011764705882352941,
        "F1": 0.02298850574712644,
        # "time_elapsed(m)": 0.0005131840705871582
    },
    "Random Forest(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.8118811881188119,
        "precision": 0.8,
        "recall": 0.1411764705882353,
        "F1": 0.24000000000000002,
        # "time_elapsed(m)": 0.08295620679855346
    },
    "Naive Bayes(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.31435643564356436,
        "precision": 0.22413793103448276,
        "recall": 0.9176470588235294,
        "F1": 0.3602771362586605,
        # "time_elapsed(m)": 0.00016666650772094725
    },
    "SVM(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.8143564356435643,
        "precision": 0.9166666666666666,
        "recall": 0.12941176470588237,
        "F1": 0.2268041237113402,
        # "time_elapsed(m)": 0.0038875301678975424
    }
}

df = pd.DataFrame(data).T 
df = df.round(4) 
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table1.html")
# Out:
# <style type="text/css">
# #T_6fb14_row3_col0, #T_6fb14_row3_col3, #T_6fb14_row6_col2, #T_6fb14_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_6fb14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fb14_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_6fb14_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_6fb14_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_6fb14_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fb14_level0_row0" class="row_heading level0 row0" >Logistic Regression(Average Aggregation)</th>
#       <td id="T_6fb14_row0_col0" class="data row0 col0" >0.858900</td>
#       <td id="T_6fb14_row0_col1" class="data row0 col1" >0.850000</td>
#       <td id="T_6fb14_row0_col2" class="data row0 col2" >0.400000</td>
# ...

# %%
data = {
    "Logistic Regression(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9767441860465116,
        "recall": 0.45652173913043476,
        "f1": 0.6222222222222222,
        # "time_elapsed(m)": 0.0009135325749715169
    },
    "Random Forest(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9183673469387755,
        "recall": 0.4891304347826087,
        "f1": 0.6382978723404256,
        # "time_elapsed(m)": 0.08480947415033976
    },
    "Naive Bayes(with metadata)": {
        "accuracy": 0.8287841191066998,
        "precision": 0.6419753086419753,
        "recall": 0.5652173913043478,
        "f1": 0.6011560693641618,
        # "time_elapsed(m)": 0.00021617412567138673
    },
    "SVM(with metadata)": {
        "accuracy": 0.8560794044665012,
        "precision": 1.0,
        "recall": 0.3695652173913043,
        "f1": 0.5396825396825397,
        # "time_elapsed(m)": 0.0028519749641418455
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table2.html")
# Out:
# <style type="text/css">
# #T_0251b_row0_col0, #T_0251b_row1_col0, #T_0251b_row1_col3, #T_0251b_row2_col2, #T_0251b_row3_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0251b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0251b_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_0251b_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_0251b_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_0251b_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0251b_level0_row0" class="row_heading level0 row0" >Logistic Regression(with metadata)</th>
#       <td id="T_0251b_row0_col0" class="data row0 col0" >0.873400</td>
#       <td id="T_0251b_row0_col1" class="data row0 col1" >0.976700</td>
#       <td id="T_0251b_row0_col2" class="data row0 col2" >0.456500</td>
# ...

# %%
data = {
    "LSTM": {
        "accuracy": 0.8319226118500604,
        "precision": 0.5797101449275363,
        "recall": 0.26666666666666666,
        "f1": 0.36529680365296796
    },
    "CNN": {
        "accuracy": 0.8524788391777509,
        "precision": 0.648936170212766,
        "recall": 0.4066666666666667,
        "f1": 0.5
    },
    "RNN": {
        "accuracy": 0.8174123337363967,
        "precision": 0.4888888888888889,
        "recall": 0.14666666666666667,
        "f1": 0.22564102564102564
    },
    "BiLSTM": {
        "accuracy": 0.8295042321644498,
        "precision": 0.5384615384615384,
        "recall": 0.42,
        "f1": 0.4719101123595505
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table3.html")
# Out:
# <style type="text/css">
# #T_d169c_row1_col0, #T_d169c_row1_col1, #T_d169c_row1_col3, #T_d169c_row3_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d169c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d169c_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_d169c_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_d169c_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_d169c_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d169c_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_d169c_row0_col0" class="data row0 col0" >0.831900</td>
#       <td id="T_d169c_row0_col1" class="data row0 col1" >0.579700</td>
#       <td id="T_d169c_row0_col2" class="data row0 col2" >0.266700</td>
#       <td id="T_d169c_row0_col3" class="data row0 col3" >0.365300</td>
#     </tr>
# ...

# %%
data = {
    "Logistic Regression(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "f1": 0.544,
        # "time_elapsed(m)": 0.0010570605595906575
    },
    "Random Forest(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "f1": 0.544,
        # "time_elapsed(m)": 0.08546341260274251
    },
    "Naive Bayes(Average Aggregation)": {
        "accuracy": 0.7673267326732673,
        "precision": 0.46017699115044247,
        "recall": 0.611764705882353,
        "f1": 0.5252525252525252,
        # "time_elapsed(m)": 0.0002043445905049642
    },
    "SVM(Average Aggregation)": {
        "accuracy": 0.8985148514851485,
        "precision": 0.8928571428571429,
        "recall": 0.5882352941176471,
        "f1": 0.7092198581560284,
        # "time_elapsed(m)": 0.0039326230684916174
    },
        "Logistic Regression(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9767441860465116,
        "recall": 0.45652173913043476,
        "f1": 0.6222222222222222,
        # "time_elapsed(m)": 0.0009135325749715169
    },
    "Random Forest(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9183673469387755,
        "recall": 0.4891304347826087,
        "f1": 0.6382978723404256,
        # "time_elapsed(m)": 0.08480947415033976
    },
    "Naive Bayes(with metadata)": {
        "accuracy": 0.8287841191066998,
        "precision": 0.6419753086419753,
        "recall": 0.5652173913043478,
        "f1": 0.6011560693641618,
        # "time_elapsed(m)": 0.00021617412567138673
    },
    "SVM(with metadata)": {
        "accuracy": 0.8560794044665012,
        "precision": 1.0,
        "recall": 0.3695652173913043,
        "f1": 0.5396825396825397,
        # "time_elapsed(m)": 0.0028519749641418455
    },
        "LSTM": {
        "accuracy": 0.8319226118500604,
        "precision": 0.5797101449275363,
        "recall": 0.26666666666666666,
        "f1": 0.36529680365296796
    },
    "CNN": {
        "accuracy": 0.8524788391777509,
        "precision": 0.648936170212766,
        "recall": 0.4066666666666667,
        "f1": 0.5
    },
    "RNN": {
        "accuracy": 0.8174123337363967,
        "precision": 0.4888888888888889,
        "recall": 0.14666666666666667,
        "f1": 0.22564102564102564
    },
    "BiLSTM": {
        "accuracy": 0.8295042321644498,
        "precision": 0.5384615384615384,
        "recall": 0.42,
        "f1": 0.4719101123595505
    },
        "Logistic Regression(TF-IDF feature)": {
        "accuracy": 0.8251231527093597,
        "precision": 0.81979695,
        "recall": 1.0,
        "f1": 0.90097629,
    },
    "Random Forest(TF-IDF feature)": {
        "accuracy": 0.8103448275862069,
        "precision": 0.8075,
        "recall": 1.0,
        "f1": 0.89349931,
    },
    "Naive Bayes(TF-IDF feature)": {
        "accuracy": 0.7955665024630542,
        "precision": 0.7955665,
        "recall": 1.0,
        "f1": 0.8861454,
    },
    "SVM(TF-IDF feature)": {
        "accuracy": 0.8300492610837439,
        "precision": 0.82397959,
        "recall": 1.0,
        "f1": 0.9034965,
    },
        "Logistic Regression(TF-IDF-Metadata)": {
        "accuracy": 0.8444444444444444,
        "precision": 0.83289125,
        "recall": 1.0,
        "f1": 0.90882779,
    },
    "Random Forest(TF-IDF-Metadata)": {
        "accuracy": 0.8641975308641975,
        "precision": 0.85094851,
        "recall": 1.0,
        "f1": 0.91947291,
    },
    "Naive Bayes(TF-IDF-Metadata)": {
        "accuracy": 0.8345679012345679,
        "precision": 0.82414698,
        "recall": 1.0,
        "f1": 0.90359712,
    },
    "SVM(TF-IDF-Metadata)": {
        "accuracy": 0.8765432098765432,
        "precision": 0.86666667,
        "recall": 0.99363057,
        "f1": 0.92581602,
    }
    
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table4.html")
# Out:
# <style type="text/css">
# #T_4c000_row3_col0, #T_4c000_row7_col1, #T_4c000_row12_col2, #T_4c000_row13_col2, #T_4c000_row14_col2, #T_4c000_row15_col2, #T_4c000_row16_col2, #T_4c000_row17_col2, #T_4c000_row18_col2, #T_4c000_row19_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4c000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c000_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_4c000_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_4c000_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_4c000_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c000_level0_row0" class="row_heading level0 row0" >Logistic Regression(Average Aggregation)</th>
#       <td id="T_4c000_row0_col0" class="data row0 col0" >0.858900</td>
# ...

# %%
data = {
    "Logistic Regression(TF-IDF feature)": {
        "accuracy": 0.8251231527093597,
        "precision": 0.81979695,
        "recall": 1.0,
        "f1": 0.90097629,
    },
    "Random Forest(TF-IDF feature)": {
        "accuracy": 0.8103448275862069,
        "precision": 0.8075,
        "recall": 1.0,
        "f1": 0.89349931,
    },
    "Naive Bayes(TF-IDF feature)": {
        "accuracy": 0.7955665024630542,
        "precision": 0.7955665,
        "recall": 1.0,
        "f1": 0.8861454,
    },
    "SVM(TF-IDF feature)": {
        "accuracy": 0.8300492610837439,
        "precision": 0.82397959,
        "recall": 1.0,
        "f1": 0.9034965,
    }
}
df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table5.html")
# Out:
# <style type="text/css">
# #T_396b3_row0_col2, #T_396b3_row1_col2, #T_396b3_row2_col2, #T_396b3_row3_col0, #T_396b3_row3_col1, #T_396b3_row3_col2, #T_396b3_row3_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_396b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_396b3_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_396b3_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_396b3_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_396b3_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_396b3_level0_row0" class="row_heading level0 row0" >Logistic Regression(TF-IDF feature)</th>
#       <td id="T_396b3_row0_col0" class="data row0 col0" >0.825100</td>
#       <td id="T_396b3_row0_col1" class="data row0 col1" >0.819800</td>
# ...

# %%
data = {
    "Logistic Regression(TF-IDF-Metadata)": {
        "accuracy": 0.8444444444444444,
        "precision": 0.83289125,
        "recall": 1.0,
        "f1": 0.90882779,
    },
    "Random Forest(TF-IDF-Metadata)": {
        "accuracy": 0.8641975308641975,
        "precision": 0.85094851,
        "recall": 1.0,
        "f1": 0.91947291,
    },
    "Naive Bayes(TF-IDF-Metadata)": {
        "accuracy": 0.8345679012345679,
        "precision": 0.82414698,
        "recall": 1.0,
        "f1": 0.90359712,
    },
    "SVM(TF-IDF-Metadata)": {
        "accuracy": 0.8765432098765432,
        "precision": 0.86666667,
        "recall": 0.99363057,
        "f1": 0.92581602,
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table6.html")
# Out:
# <style type="text/css">
# #T_097c0_row0_col2, #T_097c0_row1_col2, #T_097c0_row2_col2, #T_097c0_row3_col0, #T_097c0_row3_col1, #T_097c0_row3_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_097c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_097c0_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_097c0_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_097c0_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_097c0_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_097c0_level0_row0" class="row_heading level0 row0" >Logistic Regression(TF-IDF-Metadata)</th>
#       <td id="T_097c0_row0_col0" class="data row0 col0" >0.844400</td>
#       <td id="T_097c0_row0_col1" class="data row0 col1" >0.832900</td>
#       <td id="T_097c0_row0_col2" class="data row0 col2" >1.000000</td>
# ...
