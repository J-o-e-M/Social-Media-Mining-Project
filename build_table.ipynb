# %%
import pandas as pd
from IPython.display import display

# %%
data = {
    "Logistic Regression(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "F1": 0.544,
        # "time_elapsed(m)": 0.0010570605595906575
    },
    "Random Forest(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "F1": 0.544,
        # "time_elapsed(m)": 0.08546341260274251
    },
    "Naive Bayes(Average Aggregation)": {
        "accuracy": 0.7673267326732673,
        "precision": 0.46017699115044247,
        "recall": 0.611764705882353,
        "F1": 0.5252525252525252,
        # "time_elapsed(m)": 0.0002043445905049642
    },
    "SVM(Average Aggregation)": {
        "accuracy": 0.8985148514851485,
        "precision": 0.8928571428571429,
        "recall": 0.5882352941176471,
        "F1": 0.7092198581560284,
        # "time_elapsed(m)": 0.0039326230684916174
    },
        "Logistic Regression(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.7896039603960396,
        "precision": 0.5,
        "recall": 0.011764705882352941,
        "F1": 0.02298850574712644,
        # "time_elapsed(m)": 0.0005131840705871582
    },
    "Random Forest(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.8118811881188119,
        "precision": 0.8,
        "recall": 0.1411764705882353,
        "F1": 0.24000000000000002,
        # "time_elapsed(m)": 0.08295620679855346
    },
    "Naive Bayes(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.31435643564356436,
        "precision": 0.22413793103448276,
        "recall": 0.9176470588235294,
        "F1": 0.3602771362586605,
        # "time_elapsed(m)": 0.00016666650772094725
    },
    "SVM(TF-IDF Weighted Average Aggregation)": {
        "accuracy": 0.8143564356435643,
        "precision": 0.9166666666666666,
        "recall": 0.12941176470588237,
        "F1": 0.2268041237113402,
        # "time_elapsed(m)": 0.0038875301678975424
    }
}

df = pd.DataFrame(data).T 
df = df.round(4) 
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table1.html")
# Out:
# <style type="text/css">
# #T_2466b_row3_col0, #T_2466b_row3_col3, #T_2466b_row6_col2, #T_2466b_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2466b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2466b_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_2466b_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_2466b_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_2466b_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2466b_level0_row0" class="row_heading level0 row0" >Logistic Regression(Average Aggregation)</th>
#       <td id="T_2466b_row0_col0" class="data row0 col0" >0.858900</td>
#       <td id="T_2466b_row0_col1" class="data row0 col1" >0.850000</td>
#       <td id="T_2466b_row0_col2" class="data row0 col2" >0.400000</td>
#       <td id="T_2466b_row0_col3" class="data row0 col3" >0.544000</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row1" class="row_heading level0 row1" >Random Forest(Average Aggregation)</th>
#       <td id="T_2466b_row1_col0" class="data row1 col0" >0.858900</td>
#       <td id="T_2466b_row1_col1" class="data row1 col1" >0.850000</td>
#       <td id="T_2466b_row1_col2" class="data row1 col2" >0.400000</td>
#       <td id="T_2466b_row1_col3" class="data row1 col3" >0.544000</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row2" class="row_heading level0 row2" >Naive Bayes(Average Aggregation)</th>
#       <td id="T_2466b_row2_col0" class="data row2 col0" >0.767300</td>
#       <td id="T_2466b_row2_col1" class="data row2 col1" >0.460200</td>
#       <td id="T_2466b_row2_col2" class="data row2 col2" >0.611800</td>
#       <td id="T_2466b_row2_col3" class="data row2 col3" >0.525300</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row3" class="row_heading level0 row3" >SVM(Average Aggregation)</th>
#       <td id="T_2466b_row3_col0" class="data row3 col0" >0.898500</td>
#       <td id="T_2466b_row3_col1" class="data row3 col1" >0.892900</td>
#       <td id="T_2466b_row3_col2" class="data row3 col2" >0.588200</td>
#       <td id="T_2466b_row3_col3" class="data row3 col3" >0.709200</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row4" class="row_heading level0 row4" >Logistic Regression(TF-IDF Weighted Average Aggregation)</th>
#       <td id="T_2466b_row4_col0" class="data row4 col0" >0.789600</td>
#       <td id="T_2466b_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_2466b_row4_col2" class="data row4 col2" >0.011800</td>
#       <td id="T_2466b_row4_col3" class="data row4 col3" >0.023000</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row5" class="row_heading level0 row5" >Random Forest(TF-IDF Weighted Average Aggregation)</th>
#       <td id="T_2466b_row5_col0" class="data row5 col0" >0.811900</td>
#       <td id="T_2466b_row5_col1" class="data row5 col1" >0.800000</td>
#       <td id="T_2466b_row5_col2" class="data row5 col2" >0.141200</td>
#       <td id="T_2466b_row5_col3" class="data row5 col3" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row6" class="row_heading level0 row6" >Naive Bayes(TF-IDF Weighted Average Aggregation)</th>
#       <td id="T_2466b_row6_col0" class="data row6 col0" >0.314400</td>
#       <td id="T_2466b_row6_col1" class="data row6 col1" >0.224100</td>
#       <td id="T_2466b_row6_col2" class="data row6 col2" >0.917600</td>
#       <td id="T_2466b_row6_col3" class="data row6 col3" >0.360300</td>
#     </tr>
#     <tr>
#       <th id="T_2466b_level0_row7" class="row_heading level0 row7" >SVM(TF-IDF Weighted Average Aggregation)</th>
#       <td id="T_2466b_row7_col0" class="data row7 col0" >0.814400</td>
#       <td id="T_2466b_row7_col1" class="data row7 col1" >0.916700</td>
#       <td id="T_2466b_row7_col2" class="data row7 col2" >0.129400</td>
#       <td id="T_2466b_row7_col3" class="data row7 col3" >0.226800</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = {
    "Logistic Regression(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9767441860465116,
        "recall": 0.45652173913043476,
        "f1": 0.6222222222222222,
        # "time_elapsed(m)": 0.0009135325749715169
    },
    "Random Forest(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9183673469387755,
        "recall": 0.4891304347826087,
        "f1": 0.6382978723404256,
        # "time_elapsed(m)": 0.08480947415033976
    },
    "Naive Bayes(with metadata)": {
        "accuracy": 0.8287841191066998,
        "precision": 0.6419753086419753,
        "recall": 0.5652173913043478,
        "f1": 0.6011560693641618,
        # "time_elapsed(m)": 0.00021617412567138673
    },
    "SVM(with metadata)": {
        "accuracy": 0.8560794044665012,
        "precision": 1.0,
        "recall": 0.3695652173913043,
        "f1": 0.5396825396825397,
        # "time_elapsed(m)": 0.0028519749641418455
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table2.html")
# Out:
# <style type="text/css">
# #T_d8c49_row0_col0, #T_d8c49_row1_col0, #T_d8c49_row1_col3, #T_d8c49_row2_col2, #T_d8c49_row3_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d8c49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8c49_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_d8c49_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_d8c49_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_d8c49_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8c49_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_d8c49_row0_col0" class="data row0 col0" >0.873400</td>
#       <td id="T_d8c49_row0_col1" class="data row0 col1" >0.976700</td>
#       <td id="T_d8c49_row0_col2" class="data row0 col2" >0.456500</td>
#       <td id="T_d8c49_row0_col3" class="data row0 col3" >0.622200</td>
#     </tr>
#     <tr>
#       <th id="T_d8c49_level0_row1" class="row_heading level0 row1" >Random Forest</th>
#       <td id="T_d8c49_row1_col0" class="data row1 col0" >0.873400</td>
#       <td id="T_d8c49_row1_col1" class="data row1 col1" >0.918400</td>
#       <td id="T_d8c49_row1_col2" class="data row1 col2" >0.489100</td>
#       <td id="T_d8c49_row1_col3" class="data row1 col3" >0.638300</td>
#     </tr>
#     <tr>
#       <th id="T_d8c49_level0_row2" class="row_heading level0 row2" >Naive Bayes</th>
#       <td id="T_d8c49_row2_col0" class="data row2 col0" >0.828800</td>
#       <td id="T_d8c49_row2_col1" class="data row2 col1" >0.642000</td>
#       <td id="T_d8c49_row2_col2" class="data row2 col2" >0.565200</td>
#       <td id="T_d8c49_row2_col3" class="data row2 col3" >0.601200</td>
#     </tr>
#     <tr>
#       <th id="T_d8c49_level0_row3" class="row_heading level0 row3" >SVM</th>
#       <td id="T_d8c49_row3_col0" class="data row3 col0" >0.856100</td>
#       <td id="T_d8c49_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_d8c49_row3_col2" class="data row3 col2" >0.369600</td>
#       <td id="T_d8c49_row3_col3" class="data row3 col3" >0.539700</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = {
    "LSTM": {
        "accuracy": 0.8319226118500604,
        "precision": 0.5797101449275363,
        "recall": 0.26666666666666666,
        "f1": 0.36529680365296796
    },
    "CNN": {
        "accuracy": 0.8524788391777509,
        "precision": 0.648936170212766,
        "recall": 0.4066666666666667,
        "f1": 0.5
    },
    "RNN": {
        "accuracy": 0.8174123337363967,
        "precision": 0.4888888888888889,
        "recall": 0.14666666666666667,
        "f1": 0.22564102564102564
    },
    "BiLSTM": {
        "accuracy": 0.8295042321644498,
        "precision": 0.5384615384615384,
        "recall": 0.42,
        "f1": 0.4719101123595505
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table3.html")
# Out:
# <style type="text/css">
# #T_17c83_row1_col0, #T_17c83_row1_col1, #T_17c83_row1_col3, #T_17c83_row3_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_17c83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17c83_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_17c83_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_17c83_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_17c83_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17c83_level0_row0" class="row_heading level0 row0" >LSTM</th>
#       <td id="T_17c83_row0_col0" class="data row0 col0" >0.831900</td>
#       <td id="T_17c83_row0_col1" class="data row0 col1" >0.579700</td>
#       <td id="T_17c83_row0_col2" class="data row0 col2" >0.266700</td>
#       <td id="T_17c83_row0_col3" class="data row0 col3" >0.365300</td>
#     </tr>
#     <tr>
#       <th id="T_17c83_level0_row1" class="row_heading level0 row1" >CNN</th>
#       <td id="T_17c83_row1_col0" class="data row1 col0" >0.852500</td>
#       <td id="T_17c83_row1_col1" class="data row1 col1" >0.648900</td>
#       <td id="T_17c83_row1_col2" class="data row1 col2" >0.406700</td>
#       <td id="T_17c83_row1_col3" class="data row1 col3" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_17c83_level0_row2" class="row_heading level0 row2" >RNN</th>
#       <td id="T_17c83_row2_col0" class="data row2 col0" >0.817400</td>
#       <td id="T_17c83_row2_col1" class="data row2 col1" >0.488900</td>
#       <td id="T_17c83_row2_col2" class="data row2 col2" >0.146700</td>
#       <td id="T_17c83_row2_col3" class="data row2 col3" >0.225600</td>
#     </tr>
#     <tr>
#       <th id="T_17c83_level0_row3" class="row_heading level0 row3" >BiLSTM</th>
#       <td id="T_17c83_row3_col0" class="data row3 col0" >0.829500</td>
#       <td id="T_17c83_row3_col1" class="data row3 col1" >0.538500</td>
#       <td id="T_17c83_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_17c83_row3_col3" class="data row3 col3" >0.471900</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = {
    "Logistic Regression(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "f1": 0.544,
        # "time_elapsed(m)": 0.0010570605595906575
    },
    "Random Forest(Average Aggregation)": {
        "accuracy": 0.8589108910891089,
        "precision": 0.85,
        "recall": 0.4,
        "f1": 0.544,
        # "time_elapsed(m)": 0.08546341260274251
    },
    "Naive Bayes(Average Aggregation)": {
        "accuracy": 0.7673267326732673,
        "precision": 0.46017699115044247,
        "recall": 0.611764705882353,
        "f1": 0.5252525252525252,
        # "time_elapsed(m)": 0.0002043445905049642
    },
    "SVM(Average Aggregation)": {
        "accuracy": 0.8985148514851485,
        "precision": 0.8928571428571429,
        "recall": 0.5882352941176471,
        "f1": 0.7092198581560284,
        # "time_elapsed(m)": 0.0039326230684916174
    },
        "Logistic Regression(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9767441860465116,
        "recall": 0.45652173913043476,
        "f1": 0.6222222222222222,
        # "time_elapsed(m)": 0.0009135325749715169
    },
    "Random Forest(with metadata)": {
        "accuracy": 0.8734491315136477,
        "precision": 0.9183673469387755,
        "recall": 0.4891304347826087,
        "f1": 0.6382978723404256,
        # "time_elapsed(m)": 0.08480947415033976
    },
    "Naive Bayes(with metadata)": {
        "accuracy": 0.8287841191066998,
        "precision": 0.6419753086419753,
        "recall": 0.5652173913043478,
        "f1": 0.6011560693641618,
        # "time_elapsed(m)": 0.00021617412567138673
    },
    "SVM(with metadata)": {
        "accuracy": 0.8560794044665012,
        "precision": 1.0,
        "recall": 0.3695652173913043,
        "f1": 0.5396825396825397,
        # "time_elapsed(m)": 0.0028519749641418455
    },
        "LSTM": {
        "accuracy": 0.8319226118500604,
        "precision": 0.5797101449275363,
        "recall": 0.26666666666666666,
        "f1": 0.36529680365296796
    },
    "CNN": {
        "accuracy": 0.8524788391777509,
        "precision": 0.648936170212766,
        "recall": 0.4066666666666667,
        "f1": 0.5
    },
    "RNN": {
        "accuracy": 0.8174123337363967,
        "precision": 0.4888888888888889,
        "recall": 0.14666666666666667,
        "f1": 0.22564102564102564
    },
    "BiLSTM": {
        "accuracy": 0.8295042321644498,
        "precision": 0.5384615384615384,
        "recall": 0.42,
        "f1": 0.4719101123595505
    }
}

df = pd.DataFrame(data).T
df = df.round(4)
#output to a nice table
styled_df = df.style.apply(lambda x: ["font-weight: bold" if v == x.max() else "" for v in x], axis=0)
display(styled_df)
# Export the table to a nice looking html file with table lines
styled_df.set_table_styles(
    [{'selector': 'th, td', 'props': [('border', '1px solid black')]}]
).to_html("table4.html")
# Out:
# <style type="text/css">
# #T_8b999_row2_col2, #T_8b999_row3_col0, #T_8b999_row3_col3, #T_8b999_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8b999">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b999_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_8b999_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_8b999_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_8b999_level0_col3" class="col_heading level0 col3" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b999_level0_row0" class="row_heading level0 row0" >Logistic Regression(Average Aggregation)</th>
#       <td id="T_8b999_row0_col0" class="data row0 col0" >0.858900</td>
#       <td id="T_8b999_row0_col1" class="data row0 col1" >0.850000</td>
#       <td id="T_8b999_row0_col2" class="data row0 col2" >0.400000</td>
#       <td id="T_8b999_row0_col3" class="data row0 col3" >0.544000</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row1" class="row_heading level0 row1" >Random Forest(Average Aggregation)</th>
#       <td id="T_8b999_row1_col0" class="data row1 col0" >0.858900</td>
#       <td id="T_8b999_row1_col1" class="data row1 col1" >0.850000</td>
#       <td id="T_8b999_row1_col2" class="data row1 col2" >0.400000</td>
#       <td id="T_8b999_row1_col3" class="data row1 col3" >0.544000</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row2" class="row_heading level0 row2" >Naive Bayes(Average Aggregation)</th>
#       <td id="T_8b999_row2_col0" class="data row2 col0" >0.767300</td>
#       <td id="T_8b999_row2_col1" class="data row2 col1" >0.460200</td>
#       <td id="T_8b999_row2_col2" class="data row2 col2" >0.611800</td>
#       <td id="T_8b999_row2_col3" class="data row2 col3" >0.525300</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row3" class="row_heading level0 row3" >SVM(Average Aggregation)</th>
#       <td id="T_8b999_row3_col0" class="data row3 col0" >0.898500</td>
#       <td id="T_8b999_row3_col1" class="data row3 col1" >0.892900</td>
#       <td id="T_8b999_row3_col2" class="data row3 col2" >0.588200</td>
#       <td id="T_8b999_row3_col3" class="data row3 col3" >0.709200</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row4" class="row_heading level0 row4" >Logistic Regression(with metadata)</th>
#       <td id="T_8b999_row4_col0" class="data row4 col0" >0.873400</td>
#       <td id="T_8b999_row4_col1" class="data row4 col1" >0.976700</td>
#       <td id="T_8b999_row4_col2" class="data row4 col2" >0.456500</td>
#       <td id="T_8b999_row4_col3" class="data row4 col3" >0.622200</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row5" class="row_heading level0 row5" >Random Forest(with metadata)</th>
#       <td id="T_8b999_row5_col0" class="data row5 col0" >0.873400</td>
#       <td id="T_8b999_row5_col1" class="data row5 col1" >0.918400</td>
#       <td id="T_8b999_row5_col2" class="data row5 col2" >0.489100</td>
#       <td id="T_8b999_row5_col3" class="data row5 col3" >0.638300</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row6" class="row_heading level0 row6" >Naive Bayes(with metadata)</th>
#       <td id="T_8b999_row6_col0" class="data row6 col0" >0.828800</td>
#       <td id="T_8b999_row6_col1" class="data row6 col1" >0.642000</td>
#       <td id="T_8b999_row6_col2" class="data row6 col2" >0.565200</td>
#       <td id="T_8b999_row6_col3" class="data row6 col3" >0.601200</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row7" class="row_heading level0 row7" >SVM(with metadata)</th>
#       <td id="T_8b999_row7_col0" class="data row7 col0" >0.856100</td>
#       <td id="T_8b999_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_8b999_row7_col2" class="data row7 col2" >0.369600</td>
#       <td id="T_8b999_row7_col3" class="data row7 col3" >0.539700</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row8" class="row_heading level0 row8" >LSTM</th>
#       <td id="T_8b999_row8_col0" class="data row8 col0" >0.831900</td>
#       <td id="T_8b999_row8_col1" class="data row8 col1" >0.579700</td>
#       <td id="T_8b999_row8_col2" class="data row8 col2" >0.266700</td>
#       <td id="T_8b999_row8_col3" class="data row8 col3" >0.365300</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row9" class="row_heading level0 row9" >CNN</th>
#       <td id="T_8b999_row9_col0" class="data row9 col0" >0.852500</td>
#       <td id="T_8b999_row9_col1" class="data row9 col1" >0.648900</td>
#       <td id="T_8b999_row9_col2" class="data row9 col2" >0.406700</td>
#       <td id="T_8b999_row9_col3" class="data row9 col3" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row10" class="row_heading level0 row10" >RNN</th>
#       <td id="T_8b999_row10_col0" class="data row10 col0" >0.817400</td>
#       <td id="T_8b999_row10_col1" class="data row10 col1" >0.488900</td>
#       <td id="T_8b999_row10_col2" class="data row10 col2" >0.146700</td>
#       <td id="T_8b999_row10_col3" class="data row10 col3" >0.225600</td>
#     </tr>
#     <tr>
#       <th id="T_8b999_level0_row11" class="row_heading level0 row11" >BiLSTM</th>
#       <td id="T_8b999_row11_col0" class="data row11 col0" >0.829500</td>
#       <td id="T_8b999_row11_col1" class="data row11 col1" >0.538500</td>
#       <td id="T_8b999_row11_col2" class="data row11 col2" >0.420000</td>
#       <td id="T_8b999_row11_col3" class="data row11 col3" >0.471900</td>
#     </tr>
#   </tbody>
# </table>
